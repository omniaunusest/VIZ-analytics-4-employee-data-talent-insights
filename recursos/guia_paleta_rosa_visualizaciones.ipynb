# %% [markdown]
# # 🎨 Paleta Rosa para Visualizaciones — Guía Completa
#
# Este notebook contiene la paleta rosa profesional, cómo aplicarla en distintos tipos de gráficos, un mapa de color continuo, reglas para elegir colores y una versión alternativa pastel.
#
# ---
#
# ## 🎨 1. Paleta Rosa Profesional (9 tonos)
#
# Inspirada en **Material Design Pink & Deep Pink**, ideal para visualizaciones:
#
# ✔ Tonos claros, medios y oscuros
# ✔ Funciona en gráficos con *hue*
# ✔ Útil para gradientes (heatmaps)
# ✔ Buena accesibilidad por contraste
#
# ```python
# paleta_rosas = [
#     "#880E4F",  # rosa muy oscuro
#     "#AD1457",
#     "#C2185B",
#     "#D81B60",
#     "#E91E63",  # rosa principal
#     "#F06292",
#     "#F48FB1",
#     "#F8BBD0",
#     "#FCE4EC"   # rosa muy claro
# ]
# ```
#
# ---
#
# ## 🌈 2. Cómo usar la paleta en cada tipo de gráfico
#
# ### 🔹 A. Countplot o barplot con hue
#
# ```python
# sns.countplot(
#     data=df,
#     x="department",
#     hue="gender",
#     palette=paleta_rosas
# )
# ```
#
# ---
#
# ### 🔹 B. Boxplot con hue
#
# ```python
# sns.boxplot(
#     data=df,
#     x="department",
#     y="monthlyincome",
#     hue="gender",
#     palette=paleta_rosas[:2]   # solo dos colores
# )
# ```
#
# 📌 **Regla:** Si el hue tiene solo 2 categorías → usar solo `paleta_rosas[:2]`.
#
# ---
#
# ### 🔹 C. Gráficos sin hue (un solo color)
#
# ```python
# sns.histplot(data=df, x="age", color=paleta_rosas[3])
# ```
#
# ---
#
# ### 🔹 D. Gráficos de línea
#
# ```python
# plt.plot(df["yearsatcompany"], color=paleta_rosas[2])
# ```
#
# ---
#
# ### 🔹 E. Heatmap (mapa de color continuo)
#
# ```python
# from matplotlib.colors import LinearSegmentedColormap
# cmap_rosas = LinearSegmentedColormap.from_list("rosas", paleta_rosas)
#
# sns.heatmap(df.corr(), cmap=cmap_rosas)
# ```
#
# ---
#
# ## 🧠 3. Cuándo usar qué colores
#
# | Tipo de gráfico | Recomendación |
# |------------------|--------------|
# | hue con 2 categorías | `paleta_rosas[:2]` |
# | hue con 3–6 categorías | Paleta completa |
# | sin hue | `paleta_rosas[3]` o `paleta_rosas[4]` |
# | heatmap / escalas continuas | `cmap_rosas` |
# | gráficas de línea | Tonos medios `paleta_rosas[2:5]` |
# | barras sin hue | `paleta_rosas[4]` |
#
# ---
#
# ## ⭐ 4. Configuración global del estilo
#
# Recomendado para que **todas tus visualizaciones compartan estilo**:
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# from matplotlib.colors import LinearSegmentedColormap
#
# # Paleta rosa
# paleta_rosas = [
#     "#880E4F", "#AD1457", "#C2185B", "#D81B60", "#E91E63",
#     "#F06292", "#F48FB1", "#F8BBD0", "#FCE4EC"
# ]
#
# # Mapa de color continuo
# cmap_rosas = LinearSegmentedColormap.from_list("rosas", paleta_rosas)
#
# # Estilo global
# sns.set_theme(style="whitegrid", palette=paleta_rosas)
# ```
#
# ✔ Aplica tu paleta a todos los gráficos
# ✔ Unifica colores del proyecto
# ✔ Aporta identidad visual elegante
#
# ---
#
# ## 💕 BONUS: Paleta Rosa Pastel Alternativa
#
# ```python
# paleta_rosas_soft = [
#     "#B30059",
#     "#D14782",
#     "#E66A9C",
#     "#F28FB9",
#     "#FAC9DF"
# ]
# ```

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Paleta principal
paleta_rosas = [
    "#880E4F", "#AD1457", "#C2185B", "#D81B60", "#E91E63",
    "#F06292", "#F48FB1", "#F8BBD0", "#FCE4EC"
]

# Paleta pastel
paleta_rosas_soft = [
    "#B30059", "#D14782", "#E66A9C", "#F28FB9", "#FAC9DF"
]

# cmap continuo
cmap_rosas = LinearSegmentedColormap.from_list("rosas", paleta_rosas)

# Estilo global
sns.set_theme(style="whitegrid", palette=paleta_rosas)

paleta_rosas, cmap_rosas
