# %% [markdown]
# # 🎨 Paleta Rosa para Visualizaciones
#
# Este notebook incluye la configuración de la paleta rosa, un mapa de color continuo y ejemplos de uso.
#
# ## 1. Definir la paleta rosa
# ```python
# paleta_rosas = [
#     "#880E4F", "#AD1457", "#C2185B", "#D81B60", "#E91E63",
#     "#F06292", "#F48FB1", "#F8BBD0", "#FCE4EC"
# ]
# ```
#
# ## 2. Crear cmap continuo
# ```python
# from matplotlib.colors import LinearSegmentedColormap
# cmap_rosas = LinearSegmentedColormap.from_list("rosas", paleta_rosas)
# ```
#
# ## 3. Estilo global
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.set_theme(style="whitegrid", palette=paleta_rosas)
# ```
#
# ## 4. Ejemplo: Countplot
# ```python
# sns.countplot(data=df, x="department", hue="gender", palette=paleta_rosas[:2])
# plt.xticks(rotation=45);
# ```

# %%
# Ejecutar esta celda para cargar todo
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

paleta_rosas = [
    "#880E4F", "#AD1457", "#C2185B", "#D81B60", "#E91E63",
    "#F06292", "#F48FB1", "#F8BBD0", "#FCE4EC"
]

cmap_rosas = LinearSegmentedColormap.from_list("rosas", paleta_rosas)

sns.set_theme(style="whitegrid", palette=paleta_rosas)

paleta_rosas, cmap_rosas
