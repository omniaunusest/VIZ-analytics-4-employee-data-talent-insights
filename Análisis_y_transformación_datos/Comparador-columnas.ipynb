# %%
import pandas as pd

# %%
df= pd.read_csv('raw_data.csv')
dftrans = pd.read_csv('raw_data_limpio_2.csv')

def rawdata(df, columna):
    valores_unicos = df[columna].nunique()
    num_registros = len(df[columna])
    duplicados = num_registros - valores_unicos

    print(f"Valores únicos en archivo original: {valores_unicos}\nNúmero de registros: {num_registros}\nRegistros duplicados: {duplicados}")
    print('----------------')
    print("\nPorcentajes:")
    print(df[columna]
        .value_counts(normalize=True, dropna=False)
        .mul(100)
        .round(2)
        .sort_values(ascending=False))

# %%
# Con esta función hacemos la misma petición pero para el archivo transformado

dftrans= pd.read_csv('raw_data_limpio_2.csv')

def cambios(dftrans, columna):
        valores_unicos = dftrans[columna].nunique()
        num_registros = len(dftrans[columna])
        duplicados = num_registros - valores_unicos

        print(f"Valores únicos en archivo transformado: {valores_unicos}\nNúmero de registros:{num_registros}\nRegistros duplicados: {duplicados}")

        print('----------------')

        print("\nPorcentajes:")
        print(dftrans[columna]
        .value_counts(normalize=True, dropna=False)
        .mul(100)
        .round(2)
        .sort_values(ascending=False))

# %%
# USO:

rawdata(df, "age")
print('\n-----<------<-------<---@\n')
cambios(dftrans, "age")
# Out:
# Valores únicos en archivo original: 54
# Número de registros: 1678
# Registros duplicados: 1624
# ----------------
#
# Porcentajes:
# age
# 35              5.24
# 31              5.24
# 34              5.13
# 29              4.89
# 36              4.71
# 32              3.93
# 30              3.87
# 38              3.81
# 33              3.75
# 40              3.58
# 28              3.22
# 37              3.22
# 27              3.22
# 45              2.98
# 42              2.98
# 41              2.86
# 39              2.74
# 26              2.74
# 43              2.50
# 46              2.26
# 44              2.03
# 50              2.03
# 47              1.79
# 24              1.73
# 25              1.67
# 49              1.55
# 55              1.49
# 51              1.31
# 48              1.31
# 53              1.19
# 54              1.19
# 52              1.07
# 56              1.07
# 22              1.01
# 21              1.01
# 58              0.95
# 23              0.89
# 59              0.66
# 20              0.66
# 18              0.54
# 19              0.54
# 57              0.36
# 60              0.30
# twenty-four     0.12
# thirty-two      0.12
# forty-seven     0.06
# thirty-six      0.06
# fifty-eight     0.06
# fifty-two       0.06
# thirty-one      0.06
# thirty          0.06
# fifty-five      0.06
# twenty-six      0.06
# thirty-seven    0.06
# Name: proportion, dtype: float64
#
# -----<------<-------<---@
#
# Valores únicos en archivo transformado: 43
# Número de registros:1614
# Registros duplicados: 1571
# ----------------
#
# Porcentajes:
# age
# 35    5.20
# 34    5.20
# 31    5.14
# 29    4.83
# 36    4.65
# 32    4.09
# 30    3.97
# 38    3.97
# 33    3.78
# 40    3.72
# 27    3.35
# 37    3.35
# 28    3.28
# 42    3.10
# 45    2.97
# 41    2.85
# 26    2.85
# 39    2.79
# 43    2.48
# 46    2.35
# 44    2.11
# 50    1.92
# 25    1.67
# 47    1.67
# 24    1.61
# 49    1.55
# 55    1.55
# 51    1.24
# 54    1.24
# 53    1.24
# 48    1.24
# 52    1.18
# 56    1.05
# 21    0.99
# 22    0.99
# 23    0.93
# 58    0.93
# 20    0.68
# 59    0.62
# 19    0.56
# 18    0.50
# 60    0.31
# 57    0.31
# Name: proportion, dtype: float64
