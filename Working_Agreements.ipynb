# %% [markdown]
# ### Working Agreements - Proyecto 3: Transformando el talento
#
# ##### Miembros del equipo: Andrea, Claudia, Mayka, Ona y Patricia
#
# ##### Scrum Master: Patricia
#
# #### 1. Nos comprometemos a:
# ##### - a partir de las 20.00 no esperamos respuesta, a no ser que estemos disponibles y queramos responder
# ##### - uso del tablero: cada vez que terminemos una tarea o desglose, actualizamos el tablero
# ##### - asegurarnos de hacer pull antes de hacer push
# ##### - avisar por slack cada vez que hagamos push, pull, o actualicemos tablero
# ##### - chinchetar informacion hablada por slack que sea útil
# ##### - utilizar los hilos en slack!! Utilizar palabras clave / hashtag para poder identificarlo fácilmente
# ##### - empatía, respeto, comunicación, sinceridad
# ##### - apoyarnos entre nosotras, comunicar si necesitamos cambio/ayuda
# ##### - siempre ponernos al día de los que hacemos individualmente para mantener al grupo al tanto
# ##### - Viernes para Reuniones de resumen de la semana
# ##### - documento de ideas para la presentacion (markdown) + hilo en slack para ideas
#
#
# #### 2. Comunicación a través de:
#
# ##### - Slack: Mensajes rápidos y comunicación constante
# ##### - Zoom: Reuniones
# ##### - Github: Seguimiento de tareas y código
